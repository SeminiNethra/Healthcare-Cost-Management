# %% [markdown]
# <a href="https://colab.research.google.com/github/SeminiNethra/Healthcare-Cost-Management/blob/main/Final_Year_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy scikit-learn matplotlib seaborn

#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

#load the dataset
df = pd.read_csv('/content/Final Year Project Dataset - Sheet1 (1).csv')

#view the dataset
df.head()
# Out:
# ...
#            Name  ...  What is the average halthcare bill amount?
# 0       Yuwanya  ...                              Under 10, 000
# 1       Sheshan  ...                              Under 10, 000
# 2      Piyumika  ...                              Under 10, 000
# 3      Pavithra  ...                              Under 10, 000
# 4  Raveen Silva  ...                              Under 10, 000
#
# [5 rows x 17 columns]

# %%
#replace healthcare cost categories with numerical values
cost_map = {
    "Under 10,000": 5000,
    "10,000 - 50,000": 30000,
    "50,000 - 100,000": 75000,
    "Above 1,00,000": 120000
}

correct_column_name = 'What is the average halthcare bill amount?'

#print unique values before filtering
print("Unique values before filtering:", df[correct_column_name].unique())
if correct_column_name in df.columns:
  df = df[df[correct_column_name].isin(cost_map.keys())]
  df[correct_column_name] = df[correct_column_name].map(cost_map)
else:
  print(f"Column '{correct_column_name}'not found in DataFrame")

#print unique values after filtering
print("Unique values after filtering:", df[correct_column_name].unique())

#check for missing values
print("Missing values:\n", df.isnull().sum())

#fill missing values
df.fillna(method='ffill', inplace=True)
# Out:
# Unique values before filtering: ['Under 10, 000 ' '50, 000 - 100, 000' '10, 000 - 50,000' 'Under 10, 019'
#  'Under 10, 020']
# Unique values after filtering: []
# Missing values:
#  Name                                                                     0
# Age                                                                      0
# Sex                                                                      0
# City You Live In                                                         0
# Monthly Income Level                                                     0
# Do You Have Any Chronic Disease                                          0
# If Yes, please specify                                                   0
# Have you undergone any prior surgeries or procedures?                    0
# If yes, please specify                                                   0
# Do you have any allergies?                                               0
# ...

# %%
#seperate features and targets
x = df.drop([correct_column_name], axis=1)
y = df['Monthly Income Level']

#one-hot encode categorical columns
x = pd.get_dummies(x, drop_first=True)

#Train/Test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# Model training
model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Evaluation
print("R2 Score:", r2_score(y_test, y_pred))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-414b653d5377> in <cell line: 0>()
#       1 #seperate features and targets
# ----> 2 x = df.drop([correct_column_name], axis=1)
#       3 y = df['Monthly Income Level']
#       4
#       5 #one-hot encode categorical columns
#
# NameError: name 'df' is not defined
